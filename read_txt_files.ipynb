# %%
import csv

# %%
with open("title_list.txt", newline="") as titles:
    title_reader = csv.DictReader(titles)
    for title in title_reader:
        print(title)
# Out:
# {'Title\tSubtitle\tTitle_Remark\tContinsAlias_1.Previous_Title\tContinsAlias_2.Previous_Title\tContinsAlias_3.Previous_Title\tAuthor\tEditor\tPublisher\tPub_Year\tISBN\tBinding\tEdition\tSeries_1.Title\tSeries_1.Series_Volume\tSeries_1.Series_ID\tSeries_2.Title\tSeries_2.Series_Volume\tSeries_2.Series_ID\tSeries_3.Title\tSeries_3.Series_Volume\tSeries_3.Series_ID\tContent_Level\tYBP_Select\tLC/NLM/Dewey_Class\tList_Price\tUS_List\tUS_Status\tUS_Non-Returnable\tUK_List\tUK_Status\tUK_Non-Returnable\tEst._US_Net\tEst._UK_Net\tAdded_To_List\tSlip_Date\tSlip_Subaccount\tSlip_Discount\tUK_Slip\tNON-RETURN/NON-CANCEL_YBP\tItemVendor_1.Supplier\tItemVendor_1.Purchase_Option\tItemVendor_1.List_Price\tItemVendor_1.Status\tItemVendor_1.Library_Availability\tItemVendor_1.Preview\tItemVendor_1.Downloadable\tItemVendor_1.Available_To_Consortia\tItemVendor_1.Date_Added\tItemVendor_1.eBook_Pub_Due_Date\tItemVendor_1.eCollection_ID_1\tItemVendor_1.eCollection_ID_2\tItemVendor_1.eCollection_ID_3\tIte
# ...
